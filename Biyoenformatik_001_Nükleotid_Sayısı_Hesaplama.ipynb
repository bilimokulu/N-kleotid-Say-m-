# %%
def nukleotidsay(seq):
  nukleo = {"A":0, "C":0, "G":0, "T":0}
  for nuc in seq:
    nukleo[nuc] +=1
  return nukleo

# %%
DNA="..."

# %%
sonuc = nukleotidsay(DNA)
print(sonuc)
# Out:
# {'A': 9809, 'C': 5767, 'G': 5505, 'T': 10558}

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/nuccore/NC_009884.1?report=fasta
#
# Acidianus filamentous virus 2, complete genome
